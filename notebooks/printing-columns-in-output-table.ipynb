# %%
from astropy.table import Table,Column
import astropy.units as u
import time

# %%
infile = '/home/rfinn/research/Virgo/gui-test/test1-data-rfinn-2020-Jun-12.fits'
tab = Table.read(infile)
for i,c in enumerate(tab.columns): 
    print('|',i,'|',tab.columns[i].name,'|',tab.columns[i].unit,'|',tab.columns[i].description,'  |')
# Out:
# | 0 | VFID | None | None   |
# | 1 | RA | None | None   |
# | 2 | DEC | None | None   |
# | 3 | vr | None | None   |
# | 4 | radius | None | None   |
# | 5 | HAflag | None | Halpha flag   |
# | 6 | REDSHIFT | None | redshift   |
# | 7 | ZDIST | None | redshift   |
# | 8 | GAL_RA | deg | center from galfit   |
# | 9 | GAL_DEC | deg | center from galfit   |
# | 10 | GAL_HRA | deg | center from galfit   |
# | 11 | GAL_HDEC | deg | center from galfit   |
# | 12 | ELLIP_RA | deg | center from photutil centroid   |
# | 13 | ELLIP_DEC | deg | center from photutil centroid   |
# | 14 | HA_FLAG | None | None   |
# | 15 | FILT_COR | None | max filt trans/trans at gal z   |
# | 16 | BBOX | None | None   |
# | 17 | FILTER_RATIO | None | None   |
# | 18 | GAL_XC | pix | None   |
# | 19 | GAL_XC_ERR | pix | None   |
# | 20 | GAL_YC | pix | None   |
# | 21 | GAL_YC_ERR | pix | None   |
# | 22 | GAL_MAG | mag | None   |
# | 23 | GAL_MAG_ERR | mag | None   |
# | 24 | GAL_RE | pix | None   |
# ...

# %%
for i,c in enumerate(tab.columns): 
    print(tab.columns[i].name)
# Out:
# VFID
# RA
# DEC
# vr
# radius
# HAflag
# REDSHIFT
# ZDIST
# GAL_RA
# GAL_DEC
# GAL_HRA
# GAL_HDEC
# ELLIP_RA
# ELLIP_DEC
# HA_FLAG
# FILT_COR
# BBOX
# FILTER_RATIO
# GAL_XC
# GAL_XC_ERR
# GAL_YC
# GAL_YC_ERR
# GAL_MAG
# GAL_MAG_ERR
# GAL_RE
# GAL_RE_ERR
# GAL_N
# GAL_N_ERR
# GAL_BA
# GAL_BA_ERR
# GAL_PA
# GAL_PA_ERR
# GAL_SKY
# GAL_CHISQ
# GAL_2SERSIC
# GAL_2SERSIC_ERR
# GAL_2SERSIC_ERROR
# GAL_2SERSIC_CHISQ
# GAL_SERSASYM
# GAL_SERSASYM_ERR
# GAL_SERSASYM_ERROR
# GAL_SERSASYM_CHISQ
# GAL_SERSASYM_RA
# GAL_SERSASYM_DEC
# GAL_HXC
# GAL_HXC_ERR
# GAL_HYC
# GAL_HYC_ERR
# GAL_HMAG
# GAL_HMAG_ERR
# GAL_HRE
# GAL_HRE_ERR
# GAL_HN
# GAL_HN_ERR
# GAL_HBA
# GAL_HBA_ERR
# GAL_HPA
# GAL_HPA_ERR
# GAL_HSKY
# GAL_HCHISQ
# GAL_H2SERSIC
# GAL_H2SERSIC_ERR
# GAL_H2SERSIC_ERROR
# GAL_H2SERSIC_CHISQ
# GAL_HSERSASYM
# GAL_HSERSASYM_ERR
# GAL_HSERSASYM_ERROR
# GAL_HSERSASYM_CHISQ
# GAL_HSERSASYM_RA
# GAL_HSERSASYM_DEC
# ELLIP_XCENTROID
# ELLIP_YCENTROID
# ELLIP_EPS
# ELLIP_THETA
# ELLIP_GINI
# ...

# %%
tab['RA'].description='RA from VF'
tab['RA'].unit='deg'

# %%
tab
# Out:
# <Table length=3>
#   VFID       RA       DEC       vr   ... PARTIAL_FLAG EDGEON_FLAG NUC_HA COMMENT
#             deg                      ...
#  bytes8   float32   float32  float32 ...     bool         bool     bool  bytes50
# -------- --------- --------- ------- ... ------------ ----------- ------ -------
# VFID3472 198.26337 23.084473  2537.5 ...        False       False  False
# VFID3489  197.9043 22.915457  2608.4 ...        False       False  False
# VFID3496 198.17409 22.829775  2537.6 ...        False       False  False

# %%
         
infile = '/home/rfinn/research/Virgo/gui-test2/test1-data-rfinn-2020-Jun-19.fits'
tab = Table.read(infile)
for i,c in enumerate(tab.columns): 
    print('|',i,'|',tab.columns[i].name,'|',tab.columns[i].unit,'|',tab.columns[i].description,'  |')
    if i%20 == 0:
        time.sleep(.5)
# Out:
# | 0 | VFID | None | ID from Virgo Filament catalog   |
# | 1 | RA | deg | RA from VF catalog   |
# | 2 | DEC | deg | DEC from VF catalog   |
# | 3 | vr | km / s | recession velocity from VF catalog   |
# | 4 | radius | arcsec | radius from VF catalog   |
# | 5 | HAflag | None | Halpha flag   |
# | 6 | REDSHIFT | None | redshift   |
# | 7 | ZDIST | None | redshift   |
# | 8 | GAL_RA | deg | R-band center RA from galfit   |
# | 9 | GAL_DEC | deg | R-band center DEC from galfit   |
# | 10 | GAL_HRA | deg | HA center RA from galfit   |
# | 11 | GAL_HDEC | deg | HA center DEC from galfit   |
# | 12 | ELLIP_RA | deg | R-band center RA from photutil centroid   |
# | 13 | ELLIP_DEC | deg | R-band center DEC from photutil centroid   |
# | 14 | HA_FLAG | None | shows HA emission   |
# | 15 | FILT_COR | None | max filt trans/trans at gal z   |
# | 16 | BBOX | None | location of galaxy cutout in mosaic   |
# | 17 | FILTER_RATIO | None | R/Ha ratio used in cont subtraction   |
# ...
